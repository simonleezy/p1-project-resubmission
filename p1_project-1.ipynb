# %%
import pandas as pd
import numpy as np
from numbers import Number
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
	
import pandas as pd
df = pd.read_csv(r'C:\Users\leezy\Documents\Flatiron\P1_PROJECT\AviationData.csv',encoding = 'windows-1252',low_memory=False)
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
df.head(100000)
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country   Latitude   Longitude Airport.Code  \
# ...

# %%
### The data frame was loaded correctly
df.shape
# Out:
# (88889, 31)

# %%
### We can now start to drop our columns to the more relevant ones

# %%
df = df[df['Airport.Name'] !='Missing value']

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country   Latitude   Longitude Airport.Code  \
# ...

# %%
df.tail(3)
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#          Location        Country Latitude Longitude Airport.Code Airport.Name  \
# 88886  Payson, AZ  United States  341525N  1112021W          PAN       PAYSON
# 88887  Morgan, UT  United States      NaN       NaN          NaN          NaN
# 88888  Athens, GA  United States      NaN       NaN          NaN          NaN
#
#        ... Purpose.of.flight         Air.carrier Total.Fatal.Injuries  \
# 88886  ...          Personal                 NaN                  0.0
# 88887  ...          Personal  MC CESSNA 210N LLC                  0.0
# 88888  ...          Personal                 NaN                  0.0
#
#       Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country   Latitude   Longitude Airport.Code  \
# ...

# %%
df.dropna(how="all", inplace=True)
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country   Latitude   Longitude Airport.Code  \
# ...

# %%
df.dropna(subset= ("Airport.Code" ,"Latitude","Purpose.of.flight","Air.carrier","Airport.Name","Total.Fatal.Injuries","Total.Serious.Injuries","Total.Minor.Injuries","Weather.Condition","Broad.phase.of.flight","Report.Status"))
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 45404  20001211X11573           Accident      LAX99FA051  1998-12-17
# 47988  20001212X20664           Incident      LAX00IA127  2000-03-13
# 49192  20001212X21754           Accident      LAX00FA310  2000-08-25
# 49969  20010223X00505           Accident      ANC01LA031  2001-01-19
#
#                 Location        Country   Latitude    Longitude Airport.Code  \
# 45404    LOS ANGELES, CA  United States  33.948611  -118.413611          LAX
# 47988  SAN FRANCISCO, CA  United States  37.620278      -122.38          SFO
# 49192           HILO, HI  United States  19.716667  -155.033333          KOA
# 49969     KONGIGANAK, AK  United States  59.965833  -162.866667          DUY
#
#                     Airport.Name  ... Purpose.of.flight  \
# 45404  Los Angeles International  ...           Unknown
# 47988         SAN FRANCISCO INTL  ...           Unknown
# 49192         Hilo International  ...           Unknown
# ...

# %% [markdown]
# Without all the null values we can confirm that 4 events;3 Accidents and 1 Incident have full complete data.
# 2 of the planes were on cruise and 2 were on take of when Accident happened.

# %%
assert type(df) == pd.DataFrame

# %%
df.isnull()
# Out:
#        Event.Id  Investigation.Type  Accident.Number  Event.Date  Location  \
# 0         False               False            False       False     False
# 1         False               False            False       False     False
# 2         False               False            False       False     False
# 3         False               False            False       False     False
# 4         False               False            False       False     False
# ...         ...                 ...              ...         ...       ...
# 88884     False               False            False       False     False
# 88885     False               False            False       False     False
# 88886     False               False            False       False     False
# 88887     False               False            False       False     False
# 88888     False               False            False       False     False
#
# ...

# %%
sns.heatmap(df.isnull(), yticklabels= False)
# Out:
# <Axes: >

# %%
df.dropna(subset= ("Airport.Code" ,"Latitude","Purpose.of.flight","Air.carrier","Airport.Name","Total.Fatal.Injuries","Total.Serious.Injuries","Total.Minor.Injuries"))
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 45404  20001211X11573           Accident      LAX99FA051  1998-12-17
# 47988  20001212X20664           Incident      LAX00IA127  2000-03-13
# 49192  20001212X21754           Accident      LAX00FA310  2000-08-25
# 49969  20010223X00505           Accident      ANC01LA031  2001-01-19
# 63913  20080107X00026           Accident      SEA08LA057  2008-01-01
# ...               ...                ...             ...         ...
# 88839  20221205106409           Accident      ERA23FA079  2022-12-03
# 88845  20221205106417           Accident      CEN23FA059  2022-12-05
# 88865  20221212106444           Accident      ERA23LA085  2022-12-12
# 88873  20221215106463           Accident      ERA23LA090  2022-12-14
# 88877  20221219106470           Accident      ERA23LA091  2022-12-16
#
#                 Location        Country   Latitude    Longitude Airport.Code  \
# ...

# %%
df = df.dropna(subset= ("Airport.Code" ,"Latitude","Purpose.of.flight","Air.carrier","Airport.Name","Total.Fatal.Injuries","Total.Serious.Injuries","Total.Minor.Injuries"))

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 45404  20001211X11573           Accident      LAX99FA051  1998-12-17
# 47988  20001212X20664           Incident      LAX00IA127  2000-03-13
# 49192  20001212X21754           Accident      LAX00FA310  2000-08-25
# 49969  20010223X00505           Accident      ANC01LA031  2001-01-19
# 63913  20080107X00026           Accident      SEA08LA057  2008-01-01
# ...               ...                ...             ...         ...
# 88839  20221205106409           Accident      ERA23FA079  2022-12-03
# 88845  20221205106417           Accident      CEN23FA059  2022-12-05
# 88865  20221212106444           Accident      ERA23LA085  2022-12-12
# 88873  20221215106463           Accident      ERA23LA090  2022-12-14
# 88877  20221219106470           Accident      ERA23LA091  2022-12-16
#
#                 Location        Country   Latitude    Longitude Airport.Code  \
# ...

# %% [markdown]
# ### THIS IS THE REMAINING DATA AFTER FILTERING MOST OF THE NULL VALUES AND LEAVING ROOM FOR VIZUALIZATION.

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 45404  20001211X11573           Accident      LAX99FA051  1998-12-17
# 47988  20001212X20664           Incident      LAX00IA127  2000-03-13
# 49192  20001212X21754           Accident      LAX00FA310  2000-08-25
# 49969  20010223X00505           Accident      ANC01LA031  2001-01-19
# 63913  20080107X00026           Accident      SEA08LA057  2008-01-01
# ...               ...                ...             ...         ...
# 88839  20221205106409           Accident      ERA23FA079  2022-12-03
# 88845  20221205106417           Accident      CEN23FA059  2022-12-05
# 88865  20221212106444           Accident      ERA23LA085  2022-12-12
# 88873  20221215106463           Accident      ERA23LA090  2022-12-14
# 88877  20221219106470           Accident      ERA23LA091  2022-12-16
#
#                 Location        Country   Latitude    Longitude Airport.Code  \
# ...

# %% [markdown]
# THIS IS CONFIRMING THAT THE NULL VALUES HAVE BEEN REMOVED FROM THE DATA SET AND THE ONES REMAINING ARE BECAUSE THE DATA WIL REMAIN WITH SO MANY FEW ROWS TO ANALYSE THE DATA

# %%
df = df.drop(columns="Schedule")

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 45404  20001211X11573           Accident      LAX99FA051  1998-12-17
# 47988  20001212X20664           Incident      LAX00IA127  2000-03-13
# 49192  20001212X21754           Accident      LAX00FA310  2000-08-25
# 49969  20010223X00505           Accident      ANC01LA031  2001-01-19
# 63913  20080107X00026           Accident      SEA08LA057  2008-01-01
# ...               ...                ...             ...         ...
# 88839  20221205106409           Accident      ERA23FA079  2022-12-03
# 88845  20221205106417           Accident      CEN23FA059  2022-12-05
# 88865  20221212106444           Accident      ERA23LA085  2022-12-12
# 88873  20221215106463           Accident      ERA23LA090  2022-12-14
# 88877  20221219106470           Accident      ERA23LA091  2022-12-16
#
#                 Location        Country   Latitude    Longitude Airport.Code  \
# ...

# %%
df.head(1000)
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 45404  20001211X11573           Accident      LAX99FA051  1998-12-17
# 47988  20001212X20664           Incident      LAX00IA127  2000-03-13
# 49192  20001212X21754           Accident      LAX00FA310  2000-08-25
# 49969  20010223X00505           Accident      ANC01LA031  2001-01-19
# 63913  20080107X00026           Accident      SEA08LA057  2008-01-01
# ...               ...                ...             ...         ...
# 66825  20090728X63439           Accident      CEN09CA470  2009-07-23
# 66826  20090723X54623           Accident      WPR09CA363  2009-07-23
# 66827  20090724X02446           Accident      ERA09CA416  2009-07-23
# 66829  20090727X43538           Accident      CEN09CA465  2009-07-23
# 66830  20090728X33808           Accident      CEN09CA468  2009-07-23
#
#                    Location        Country   Latitude    Longitude  \
# 45404       LOS ANGELES, CA  United States  33.948611  -118.413611
# ...

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 45404  20001211X11573           Accident      LAX99FA051  1998-12-17
# 47988  20001212X20664           Incident      LAX00IA127  2000-03-13
# 49192  20001212X21754           Accident      LAX00FA310  2000-08-25
# 49969  20010223X00505           Accident      ANC01LA031  2001-01-19
# 63913  20080107X00026           Accident      SEA08LA057  2008-01-01
# ...               ...                ...             ...         ...
# 88839  20221205106409           Accident      ERA23FA079  2022-12-03
# 88845  20221205106417           Accident      CEN23FA059  2022-12-05
# 88865  20221212106444           Accident      ERA23LA085  2022-12-12
# 88873  20221215106463           Accident      ERA23LA090  2022-12-14
# 88877  20221219106470           Accident      ERA23LA091  2022-12-16
#
#                 Location        Country   Latitude    Longitude Airport.Code  \
# ...

# %% [markdown]
# AFTER FILTERING THE DATA WE ARE LEFT WITH 7014 AND 30 COLUMNS TO DETERMINE THE MOST AIRCRAFT THAT IS MOST TO HUMAN ERROR

# %%
df.to_csv('p1project_cleaned.csv', index=False)

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 45404  20001211X11573           Accident      LAX99FA051  1998-12-17
# 47988  20001212X20664           Incident      LAX00IA127  2000-03-13
# 49192  20001212X21754           Accident      LAX00FA310  2000-08-25
# 49969  20010223X00505           Accident      ANC01LA031  2001-01-19
# 63913  20080107X00026           Accident      SEA08LA057  2008-01-01
# ...               ...                ...             ...         ...
# 88839  20221205106409           Accident      ERA23FA079  2022-12-03
# 88845  20221205106417           Accident      CEN23FA059  2022-12-05
# 88865  20221212106444           Accident      ERA23LA085  2022-12-12
# 88873  20221215106463           Accident      ERA23LA090  2022-12-14
# 88877  20221219106470           Accident      ERA23LA091  2022-12-16
#
#                 Location        Country   Latitude    Longitude Airport.Code  \
# ...

# %%
import matplotlib.pyplot as plt

# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Compute value counts for Event.Id column
value_counts = df["Event.Id"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count")
ax2.set_ylabel("Count")
ax1.set_title("Distribution of Event.Id")
ax2.set_title("Top 5 Event.Id")

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# THE TOP EVENT ID WITH THE MOST UNINJURED PEOPLE IS 2022113106354 WITH A VALUE COUNT OF 2

# %%
bar_chart_title = "Top 5 Most Common Superhero Eye Colors"

fig, ax = plt.subplots()

# plotting the bar charts
ax.bar(Air.carrier,top_Total.Fatal.Injuries)
ax.set_xlabel('Air.carrier')
ax.set_ylabel('Total.Fatal.Injuries')
ax.set_title(bar_chart_title)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       3 fig, ax = plt.subplots()
#       5 # plotting the bar charts
# ----> 6 ax.bar(Air.carrier,top_Total.Fatal.Injuries)
#       7 ax.set_xlabel('Air.carrier')
#       8 ax.set_ylabel('Total.Fatal.Injuries')
#
# NameError: name 'Air' is not defined

# %% [markdown]
# WE ARE NOW GOING TO ANALYSE THE DATA USING GRAPHS AND OTHER VISUALIZATIONS

# %%
sns.displot(df, x="Total.Uninjured")

# %% [markdown]
# WE CAN SEE THAT TOTAL.UNINJURED PEOPLE ARE LESS THAN FATAL.MINOR AND MAJOR INJURIES

# %%
sns.displot(df, x="Total.Fatal.Injuries")

# %%
sns.displot(df, x="Total.Serious.Injuries")

# %%
sns.displot(df, x="Total.Minor.Injuries")

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# TRYING TO CREATE A LINE GRAPH REPRESENTING THE ACCIDENT NUMBER AND TOTAL.MINOR.INJURIES

# %% [markdown]
# # WE NOW KNOW THAT UNITED STATES OF AMERICA HAS THE MOST FATALITIES, MAJOR AND MINOR INJURIES SO FAR
# # THAT IS BECAUSE ON THE FILTERED DATA THE AMOUNT OF TOTAL INJURIES WAS MORE THAN 6000 AND THE AMOUNT OFSERIOUS INJURIES WAS AROUND 5900; THIS GIVING A TOTAL OF MINOR INJURIES AMORE THAN 6200 ENSURING THAT FLIGHT IS ONE OF THE MOST SAFEST MODE OF TRANSPORT.

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 45404  20001211X11573           Accident      LAX99FA051  1998-12-17
# 47988  20001212X20664           Incident      LAX00IA127  2000-03-13
# 49192  20001212X21754           Accident      LAX00FA310  2000-08-25
# 49969  20010223X00505           Accident      ANC01LA031  2001-01-19
# 63913  20080107X00026           Accident      SEA08LA057  2008-01-01
# ...               ...                ...             ...         ...
# 88839  20221205106409           Accident      ERA23FA079  2022-12-03
# 88845  20221205106417           Accident      CEN23FA059  2022-12-05
# 88865  20221212106444           Accident      ERA23LA085  2022-12-12
# 88873  20221215106463           Accident      ERA23LA090  2022-12-14
# 88877  20221219106470           Accident      ERA23LA091  2022-12-16
#
#                 Location        Country   Latitude    Longitude Airport.Code  \
# ...

# %%
# convert relevant columns to numeric
numeric_columns = ['Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
#replacing unknown in broad phase of flight
df['Broad.phase.of.flight'].replace('unknown', np.nan, inplace=True)

# %%
#drop NaN values
df.dropna(subset=['Broad.phase.of.flight'], inplace=True)

# %%
#grouping by broad phase of fight and sum of injury
df_grouped = df.groupby('Broad.phase.of.flight')[numeric_columns].sum().reset_index()

# %%
#format for easie plotting
df_melted = pd.melt(df_grouped, id_vars=['Broad.phase.of.flight'],
                    value_vars=numeric_columns,
                    var_name='Injury Type', value_name='count')

# %%
#GROUPED BAR PLOT
plt.figure(figsize=(14,8))
sns.barplot(x='Broad.phase.of.flight', y='count', hue='Injury Type', data=df_melted)
plt.xlabel('Broad.phase.of.flight')
plt.ylabel('count')
plt.xticks(rotation=45)
plt.legend(title='Injury Type')

plt.tight_layout()
plt.show()

# %%
#WHERE Broad phase of flight is unknown
filtered_df = df[df['Broad.phase.of.flight'] !='unknown']

# %%
#NUMBER OF ACCIDETS IN BROAD PHASE OF FLIGHT
phase_counts = filtered_df['Broad.phase.of.flight'].value_counts()

# %%
#BAR CHART
plt.figure(figsize=(12, 6))
phase_counts.plot(kind='bar', color='blue')
plt.title('Number of Accidents')
plt.xlabel('Broad Phase of Flight')
plt.ylabel('Number of Accidents')
plt.grid(axis='y')
plt.show()
